# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.models import Sequential
from keras.layers import Activation, Dense, Dropout
from keras.callbacks import EarlyStopping

from sklearn.preprocessing import LabelBinarizer
from sklearn.model_selection import train_test_split

from nltk.corpus import stopwords
from nltk.stem.porter import PorterStemmer
import nltk
nltk.download("stopwords")
# Out:
# Using TensorFlow backend.
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\joaki\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
plt.rcParams['figure.figsize'] = (16,8)

# %% [markdown]
# # Heading 1
# # Heading 2
# ## Heading 2.1
# ## Heading 2.2
# 1. Numbered item
# 1. Numbered item

# %%
df = pd.read_csv("./winemag-data_first150k.csv")
df.head()
# Out:
#    Unnamed: 0 country                                        description  \
# 0           0      US  This tremendous 100% varietal wine hails from ...
# 1           1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2           2      US  Mac Watson honors the memory of a wine once ma...
# 3           3      US  This spent 20 months in 30% new French oak, an...
# 4           4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#             region_1           region_2             variety  \
# 0        Napa Valley               Napa  Cabernet Sauvignon
# 1               Toro                NaN       Tinta de Toro
# 2     Knights Valley             Sonoma     Sauvignon Blanc
# 3  Willamette Valley  Willamette Valley          Pinot Noir
# 4             Bandol                NaN  Provence red blend
#
#                     winery
# 0                    Heitz
# 1  Bodega Carmen Rodríguez
# 2                 Macauley
# 3                    Ponzi
# 4     Domaine de la Bégude

# %%
print(df.describe())
# Out:
#           Unnamed: 0         points          price
# count  150930.000000  150930.000000  137235.000000
# mean    75464.500000      87.888418      33.131482
# std     43569.882402       3.222392      36.322536
# min         0.000000      80.000000       4.000000
# 25%     37732.250000      86.000000      16.000000
# 50%     75464.500000      88.000000      24.000000
# 75%    113196.750000      90.000000      40.000000
# max    150929.000000     100.000000    2300.000000

# %%
print(df.shape)
df = df.drop(columns=["Unnamed: 0", "region_1", "region_2"])
df = df.dropna()
df = df.drop_duplicates(subset="description")
df.head()
print(df.shape)
# Out:
# (150930, 11)
# (61484, 8)

# %%
df.describe()
# Out:
#              points         price
# count  61484.000000  61484.000000
# mean      88.215519     36.166352
# std        3.229942     36.391130
# min       80.000000      4.000000
# 25%       86.000000     17.000000
# 50%       88.000000     27.000000
# 75%       90.000000     45.000000
# max      100.000000   2013.000000

# %%
df.head()
# Out:
#   country                                        description  \
# 0      US  This tremendous 100% varietal wine hails from ...
# 1   Spain  Ripe aromas of fig, blackberry and cassis are ...
# 2      US  Mac Watson honors the memory of a wine once ma...
# 3      US  This spent 20 months in 30% new French oak, an...
# 4  France  This is the top wine from La Bégude, named aft...
#
#                             designation  points  price        province  \
# 0                     Martha's Vineyard      96  235.0      California
# 1  Carodorum Selección Especial Reserva      96  110.0  Northern Spain
# 2         Special Selected Late Harvest      96   90.0      California
# 3                               Reserve      96   65.0          Oregon
# 4                            La Brûlade      95   66.0        Provence
#
#               variety                   winery
# 0  Cabernet Sauvignon                    Heitz
# 1       Tinta de Toro  Bodega Carmen Rodríguez
# 2     Sauvignon Blanc                 Macauley
# 3          Pinot Noir                    Ponzi
# 4  Provence red blend     Domaine de la Bégude

# %%
sns.countplot(x="points", data=df)

# %%
sns.distplot(df.price, bins=500).set(xlim=(0, 250))
# Out:
# [(0, 250)]

# %%
g = sns.countplot(x="province", data=df,  order = df['province'].value_counts().iloc[:20].index)
plt.setp(g.get_xticklabels(), rotation=45)
plt.show()

# %%
g = sns.countplot(x="variety", data=df,  order = df['variety'].value_counts().iloc[:30].index)
plt.setp(g.get_xticklabels(), rotation=45)
plt.show()

# %%
df.groupby('variety').mean().sort_values(by='points', ascending=False)['points'].iloc[:20].plot(kind='bar')

# %%
df.groupby('variety').mean().sort_values(by='price', ascending=False)['price'].iloc[:20].plot(kind='bar')

# %%
test = df.groupby('variety').mean()

test["P/P"] = test.points / test.price
test.head()
test.sort_values(by='P/P', ascending=False)['P/P'].iloc[:20].plot(kind='bar')

# %%
df.groupby('points').mean().plot()

# %%
print(df.groupby('country').mean().drop(columns=["price"]).sort_values(by="points", ascending=False))
print(df.groupby('country').mean().drop(columns=["points"]).sort_values(by="price", ascending=False))
# Out:
#                            points
# country
# England                 92.750000
# Austria                 89.551648
# Germany                 88.976310
# France                  88.884307
# Canada                  88.814159
# Italy                   88.670780
# Turkey                  88.612903
# Australia               88.450544
# US                      88.412223
# Portugal                88.328266
# Slovenia                88.243902
# New Zealand             88.089552
# Hungary                 88.073394
# Serbia                  88.000000
# South Africa            87.704516
# India                   87.666667
# Morocco                 87.600000
# Israel                  87.443366
# Luxembourg              87.000000
# Spain                   86.933694
# Cyprus                  86.750000
# Croatia                 86.577778
# Australia               88.450544  37.193090   2.378145
# US                      88.412223  38.008243   2.326133
# Italy                   88.670780  40.428987   2.193248
# Canada                  88.814159  40.646018   2.185064
# Luxembourg              87.000000  40.666667   2.139344
# France                  88.884307  44.012459   2.019526
# Germany                 88.976310  44.304379   2.008296
# England                 92.750000  47.500000   1.952632
# Hungary                 88.073394  55.440367   1.588615

# %%
temp = df[df.points > 90]
temp["bestPrice"] = temp["points"] / temp["price"]

print(temp.dropna().sort_values(by="price", ascending=True))
# Out:
#           country                                        description  \
# 19989          US  Pungent aromas of concentrated stone fruits, b...
# 110140         US  With full ripeness, density and concentration,...
# 53469          US  This tangy, all-stainless, lightly grassy, dry...
# 69461       Spain  Top-notch manzanilla, plain and simple. What's...
# 2547     Portugal  This is a fine wine, with great structure and ...
# 24580    Portugal  A very soft-textured wine with delicious jammy...
# 40946    Portugal  A firm wine, based on dry tannins and some den...
# 9263      Germany  Blue Fish Riesling consistently stuns in a bli...
# 115648  Argentina  Sensational wine for the money. The Cab and Me...
# 100496   Portugal  From Reguengos de Monsaraz in southern Alentej...
# 76968    Portugal  Full and rounded wine, with touches of toast, ...
# 24451    Portugal  With an initial smooth texture, this is a rich...
# 131604  Argentina  One of the year's best red wine values has to ...
# 72483          US  A fresh and textural wine, this puts a spicy s...
# 882      Portugal  This lightly wood-aged wine is slightly auster...
# 32591    Portugal  Made from fruit that's sourced from the Buçaco...
# 2302     Portugal  The Reserva version of Mural makes a powerful ...
# 2292        India  Aromas of blackberry, cherry preserves, white ...
# 63194          US  Delicious and refreshing, a dessert wine to ha...
# 24479    Portugal  Rich, smooth, with great wafts of creaminess t...
# 37596       Italy  Kappa is a dark, brooding super Tuscan with a ...
# 76953    Portugal  Rich, rounded and smooth, this is an exception...
# 43692      France  This is smooth, rich and elegant, with black f...
# 76653    Portugal  With its new wood flavors, this is a ripe wine...
# 142949         US  Shows why this part of the Foothills has achie...
# 76954    Portugal  A blend of Alvarinho and Loureiro, this is ric...
# 92522    Portugal  Concentrated and powerful, this is a rich and ...
# 38530    Portugal  The wood shows strongly on this still young wi...
# 110153  Argentina  A year or two ago when Paul Hobbs began consul...
# 106613         US  This is the best Pinot Gris yet from Jones; th...
# ...           ...                                                ...
# 3033    Australia  This Cabernet equivalent to Grange has explode...
# 115160     France  This comes from high up in the Chevalier-Montr...
# 128118    Germany  This TBA shows an incredible likeness to Earl ...
# 29227      France  This wine is just starting out, which explains...
# 60918      France  Orange-pink in color, this a super-rich rosé. ...
# 75823      France  Despite its power, this is so elegant, showing...
# 52274     Hungary  This famed Hungarian dessert wine never disapp...
# 57120   Australia  This is a bold, full-flavored, authoritative e...
# 36448    Portugal  Properly old gold in color, this is a wine fro...
# 115163     France  This is a beautifully shaped wine that rises f...
# 85603       Spain  Toasty and black as midnight on the nose, this...
# 10509   Australia  This is dark and concentrated, as you might ex...
# 26664     Germany  Hugely sweet yet reasonably balanced given its...
# 127614  Australia  This stellar wine takes a little time in the g...
# 18617          US  The former basketball star's initial release i...
# 110140                    Snoqualmie  11.375000
# 53469                Barnard Griffin  10.111111
# 69461         Bodegas Dios Baco S.L.  10.111111
# 2547                   Caves Aliança   9.100000
# 24580             Wines & Winemakers   9.100000
# 40946               Quinta do Portal   9.100000
# 9263                       Blue Fish   9.100000
# 115648                  Carlos Basso   9.100000
# 100496                    Granadeiro   8.272727
# 76968                     DFJ Vinhos   8.272727
# 24451              Quinta do Serrado   8.363636
# 131604                Bodega Renacer   8.272727
# 72483                    Pacific Rim   8.272727
# 882                    Pedra Cancela   8.363636
# 32591             Wines & Winemakers   8.272727
# 2302                Quinta do Portal   7.583333
# 2292                            Sula   7.583333
# 63194                  Robert Pecota   7.666667
# 24479     Bacalhôa Wines of Portugal   7.583333
# 37596                 Fattoria Kappa   7.583333
# 76953                        Aveleda   7.583333
# 43692                Château d'Aydie   7.750000
# 76653     Bacalhôa Wines of Portugal   7.583333
# 142949                  Sobon Estate   7.583333
# 76954                        Aveleda   7.583333
# 92522                        Aveleda   7.583333
# 38530   Adega Cooperativa do Cartaxo   7.583333
# 110153                  Pascual Toso   7.583333
# 106613           Jones of Washington   7.583333
# ...                              ...        ...
# 3033                        Penfolds   0.190000
# 115160          Bouchard Père & Fils   0.192000
# 128118       Schloss Reinhartshausen   0.186000
# 29227               Olivier Leflaive   0.190000
# 60918                 Louis Roederer   0.188119
# 75823           Domaine Perrot-Minot   0.182857
# 52274                   Royal Tokaji   0.174632
# 57120                       Henschke   0.174545
# 36448                Taylor Fladgate   0.161565
# 115163                Joseph Drouhin   0.161074
# 85603                 García Figuero   0.155259
# 10509                       Penfolds   0.161667
# 26664                    Robert Weil   0.158497
# 127614                      Henschke   0.152000
# 18617                       Yao Ming   0.155200
# 65335           Bouchard Père & Fils   0.145455
# 12456                    Robert Weil   0.137313
# 8838                    Louis Latour   0.125676
# 21555                   Royal Tokaji   0.123037
# 2453                    Marco Abella   0.124675
# 12434                          Kopke   0.120779
# 34212                    Robert Weil   0.122581
# 34213                    Robert Weil   0.122581
# 32453                   Biondi Santi   0.117500
# 10505                       Penfolds   0.115294
# 90744                   Biondi Santi   0.104444
# 10886                          Kopke   0.095918
# 10651                 Emmerich Knoll   0.085455
# 26296                           Krug   0.071429
# 13318                          Blair   0.045206
#
# [15209 rows x 9 columns]
# C:\Users\joaki\.conda\envs\3.7\lib\site-packages\ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
df = pd.read_csv("./winemag-data_first150k.csv")
print(df.shape)
df = df[["description","variety"]]
df = df.dropna()
df = df.drop_duplicates(subset="description")
print(df.shape)
df.head()
# Out:
# (150930, 11)
# (97821, 2)
#                                          description             variety
# 0  This tremendous 100% varietal wine hails from ...  Cabernet Sauvignon
# 1  Ripe aromas of fig, blackberry and cassis are ...       Tinta de Toro
# 2  Mac Watson honors the memory of a wine once ma...     Sauvignon Blanc
# 3  This spent 20 months in 30% new French oak, an...          Pinot Noir
# 4  This is the top wine from La Bégude, named aft...  Provence red blend

# %%
import gc
gc.collect()
# Out:
# 5046

# %%
# Clean
df.description = df.description.str.replace('[^A-Za-z\s]+', '')
df.description = df.description.str.lower()

# %%
ps = PorterStemmer()
english_words = stopwords.words('english')

def stem_sentences(sentence):
    sentence = sentence.split()
    sentence = [word for word in sentence if not word in english_words]
    sentence = [ps.stem(word) for word in sentence]
    return ' '.join(sentence)

print(df['description'].head())
df['description'] = df['description'].apply(stem_sentences)
print(df['description'].head())
# Out:
# 0    this tremendous  varietal wine hails from oakv...
# 1    ripe aromas of fig blackberry and cassis are s...
# 2    mac watson honors the memory of a wine once ma...
# 3    this spent  months in  new french oak and inco...
# 4    this is the top wine from la bgude named after...
# Name: description, dtype: object
# 0    tremend variet wine hail oakvil age three year...
# 1    ripe aroma fig blackberri cassi soften sweeten...
# 2    mac watson honor memori wine made mother treme...
# 3    spent month new french oak incorpor fruit ponz...
# 4    top wine la bgude name highest point vineyard ...
# Name: description, dtype: object

# %%
vocab_size = 10000
tokenize = Tokenizer(num_words=vocab_size)

tokenize.fit_on_texts(df.description)
print(len(tokenize.word_index) + 1)

X = tokenize.texts_to_matrix(df.description, mode='tfidf')
# Out:
# 33069

# %%
encoder = LabelBinarizer()
encoder.fit(df.variety)
Y = encoder.transform(df.variety)

# %%
x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
print(y_train.shape[1])
# Out:
# 632

# %%
input_dim = x_train.shape[1]  # Number of features
output_dim = y_train.shape[1]  # Number of features
# print(y_test.head())
model = Sequential()

model.add(Dense(128, input_dim=input_dim))
model.add(Activation('tanh'))
model.add(Dropout(0.2))

model.add(Dense(256))
model.add(Activation('sigmoid'))
model.add(Dropout(0.2))

model.add(Dense(output_dim))
model.add(Activation('softmax'))

model.compile(loss='categorical_crossentropy', metrics=['accuracy'],
              optimizer='adam')

es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=5)

model_output = model.fit(x_train, y_train,
             batch_size=32,
             epochs=100,
             verbose=2,
             callbacks=[es],
             validation_split=0.2)
# Out:
# Train on 54779 samples, validate on 13695 samples
# Epoch 1/100
#  - 42s - loss: 2.3517 - acc: 0.4871 - val_loss: 1.8052 - val_acc: 0.5822
# Epoch 2/100
#  - 19s - loss: 1.4881 - acc: 0.6454 - val_loss: 1.7447 - val_acc: 0.5930
# Epoch 3/100
#  - 23s - loss: 1.1165 - acc: 0.7195 - val_loss: 1.8159 - val_acc: 0.5926
# Epoch 4/100
#  - 23s - loss: 0.8697 - acc: 0.7720 - val_loss: 1.9650 - val_acc: 0.5830
# Epoch 5/100
#  - 24s - loss: 0.7001 - acc: 0.8122 - val_loss: 2.1506 - val_acc: 0.5777
# Epoch 6/100
#  - 26s - loss: 0.5860 - acc: 0.8411 - val_loss: 2.3482 - val_acc: 0.5771
# Epoch 7/100
#  - 22s - loss: 0.5132 - acc: 0.8592 - val_loss: 2.4510 - val_acc: 0.5715
# Epoch 00007: early stopping

# %%
print('Training Accuracy : ' , np.mean(model_output.history["acc"]))
print('Validation Accuracy : ' , np.mean(model_output.history["val_acc"]))

plt.plot(model_output.history['acc'])
plt.plot(model_output.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model_output.history['loss'])
plt.plot(model_output.history['val_loss'])
plt.title('model_output loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Training Accuracy :  0.7337770209135348
# Validation Accuracy :  0.5824336306276452
