# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import numpy as np

from sklearn.cluster import KMeans
from scipy import stats

# %%
df = pd.read_csv("./kpi.csv", header=0, na_values='.');
df.head()
# Out:
#    ticker  year  period                                  reportEndDate  \
# 0     247  2018       3  Tue Oct 30 2018 00:00:00 GMT+0100 (GMT+01:00)
# 1     247  2018       2  Mon Jul 30 2018 00:00:00 GMT+0200 (GMT+02:00)
# 2     247  2018       1  Tue May 01 2018 00:00:00 GMT+0200 (GMT+02:00)
# 3     247  2017       3  Mon Oct 30 2017 00:00:00 GMT+0100 (GMT+01:00)
# 4  2CUREX  2018       3  Tue Oct 30 2018 00:00:00 GMT+0100 (GMT+01:00)
#
#    bruttomarginal  operativtkassaflodesmarginal  vinsttillvaxt  ebittillvaxt  \
# 0       56.972054                      6.886116            NaN           NaN
# 1       53.558216                     62.985123            NaN           NaN
# 2       55.590099                    -19.031630            NaN           NaN
# 3             NaN                           NaN            NaN           NaN
# 4       39.222061                   -112.652832            NaN           NaN
#
#    omsattningstillvaxt  vinst/aktie  ...  fcf/aktie  rorelsemarginal  \
# 0                  NaN       0.0585  ...   0.031116        13.103422
# 1                  NaN       0.0402  ...   0.053366         6.262300
# 2                  NaN       0.0373  ...  -0.092223         5.600464
# 3                  NaN          NaN  ...        NaN              NaN
# 4                  NaN      -0.0939  ...  -0.503517       -21.054331
#
#    ebita/aktie  ebit/aktie  operativkassaflode/aktie  aretskassaflode/aktie  \
# 0     0.066037    0.065737                  0.034546               0.019607
# 1     0.030179    0.029822                  0.299949               0.054134
# 2     0.025717    0.025324                 -0.086056              -0.126169
# 3          NaN         NaN                       NaN                    NaN
# 4    -0.080213   -0.094502                 -0.505643              -0.503517
#
#    vinstmarginal  price  stockChange        stockChangePct
# 0      11.676132   8.50        -0.64  -0.07529411764705879
# 1       8.458632   6.44         2.06   0.31987577639751547
# 2       8.270116   6.12         0.32   0.05228758169934645
# 3            NaN    NaN         6.12              Infinity
# 4     -20.938091  14.68         2.32    0.1580381471389646
#
# [5 rows x 21 columns]

# %%
df = df[["vinsttillvaxt","omsattningstillvaxt","ebittillvaxt","bruttomarginal","vinstmarginal","operativtkassaflodesmarginal", "stockChangePct"]]

df.describe()
# Out:
#        vinsttillvaxt  omsattningstillvaxt   ebittillvaxt  bruttomarginal  \
# count    2738.000000          5616.000000    2932.000000     6131.000000
# mean      523.645271           218.274945     266.205325     -639.485419
# std     10086.242862          3247.793706    4847.079810    11985.725404
# min       -99.777779           -99.932732     -99.871986  -494400.000000
# 25%       -16.126435            -2.450127      -9.278351       22.908587
# 50%        15.335753            11.407741      14.007912       43.816254
# 75%        64.144987            38.708520      54.657435       67.124981
# max    361662.000000        150200.000000  246602.703125     5786.155273
#
#        vinstmarginal  operativtkassaflodesmarginal
# count   6.430000e+03                  5.965000e+03
# mean   -1.816350e+03                 -1.474357e+03
# std     4.455266e+04                  2.529655e+04
# min    -3.317400e+06                 -1.189100e+06
# 25%    -6.873578e+01                 -5.678676e+01
# 50%     9.881963e-01                  1.619433e+00
# 75%     8.557513e+00                  1.502503e+01
# max     2.068000e+05                  6.325000e+05

# %%
df["stockChangePct"] = df["stockChangePct"].astype(float) * 100
df = df[df["stockChangePct"] < 10000000]
df["stockChangePct"] = df["stockChangePct"].astype(int)
print(df.head())

print(df.shape)
df = df.dropna()
print(df.shape)

df.info()
# Out:
#    vinsttillvaxt  omsattningstillvaxt  ebittillvaxt  bruttomarginal  \
# 0            NaN                  NaN           NaN       56.972054
# 1            NaN                  NaN           NaN       53.558216
# 2            NaN                  NaN           NaN       55.590099
# 4            NaN                  NaN           NaN       39.222061
# 5            NaN            19.541096           NaN      -90.366768
#
#    vinstmarginal  operativtkassaflodesmarginal  stockChangePct
# 0      11.676132                      6.886116              -7
# 1       8.458632                     62.985123              31
# 2       8.270116                    -19.031630               5
# 4     -20.938091                   -112.652832              15
# 5    -383.328827                   -265.305939              72
# (6371, 7)
# (2361, 7)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2361 entries, 29 to 7023
# Data columns (total 7 columns):
# vinsttillvaxt                   2361 non-null float64
# omsattningstillvaxt             2361 non-null float64
# ebittillvaxt                    2361 non-null float64
# bruttomarginal                  2361 non-null float64
# vinstmarginal                   2361 non-null float64
# operativtkassaflodesmarginal    2361 non-null float64
# stockChangePct                  2361 non-null int32
# dtypes: float64(6), int32(1)
# memory usage: 138.3 KB

# %%
sns.distplot(df.stockChangePct)

# %%
df.stockChangePct.describe()
# Out:
# count    2361.000000
# mean        1.194409
# std        23.649307
# min      -100.000000
# 25%        -8.000000
# 50%         0.000000
# 75%         9.000000
# max       559.000000
# Name: stockChangePct, dtype: float64

# %%
df = df[df.stockChangePct > 0]

# %%
df.stockChangePct.describe()
# Out:
# count    1115.000000
# mean       14.533632
# std        24.774594
# min         1.000000
# 25%         5.000000
# 50%         9.000000
# 75%        17.000000
# max       559.000000
# Name: stockChangePct, dtype: float64

# %%
sns.distplot(df.stockChangePct)

# %%
df.describe()
# Out:
#        vinsttillvaxt  omsattningstillvaxt  ebittillvaxt  bruttomarginal  \
# count    1115.000000          1115.000000   1115.000000     1115.000000
# mean      270.315400            41.372989     98.107692       49.969282
# std      4506.908291           478.911470    753.637120       24.781498
# min       -99.773323           -84.859375    -99.532394     -240.010574
# 25%        -9.033853             3.606244      0.448123       33.370115
# 50%        21.818182            11.929926     19.282511       49.327053
# 75%        75.117928            26.200167     55.501591       69.516590
# max    148130.578125         15733.954102  22842.666016      195.493927
#
#        vinstmarginal  operativtkassaflodesmarginal  stockChangePct
# count    1115.000000                   1115.000000     1115.000000
# mean       29.929188                     14.412541       14.533632
# std        64.904077                    113.686560       24.774594
# min         0.009967                  -1425.666016        1.000000
# 25%         5.159019                      3.694307        5.000000
# 50%         9.395831                     12.301013        9.000000
# 75%        24.118567                     25.736522       17.000000
# max       810.330078                   1595.921753      559.000000

# %%
df = df[df.vinsttillvaxt > 20]
df = df[df.omsattningstillvaxt > 10]
df = df[df.ebittillvaxt > 20]
df = df[df.bruttomarginal > 50]
df = df[df.vinstmarginal > 10]
df = df[df.operativtkassaflodesmarginal > 10]

# %%
plt.figure(figsize=(15,16))
sns.distplot(df.stockChangePct)
plt.show()

# %%
import numpy as np 
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.metrics import confusion_matrix, precision_score
from sklearn.model_selection import train_test_split
from keras.layers import Dense,Dropout,Activation
from keras.models import Sequential
from keras.utils import to_categorical

from keras.callbacks import EarlyStopping


from hyperopt import Trials, STATUS_OK, tpe
from keras.utils import np_utils
from hyperas import optim
from hyperas.distributions import choice, uniform

# %%
def data():
    """
    Data providing function:

    This function is separated from create_model() so that hyperopt
    won't reload data for each evaluation run.
    """
    df = pd.read_csv("./kpi.csv", header=0, na_values='.', encoding="utf8")
    df = df[["vinsttillvaxt","omsattningstillvaxt","ebittillvaxt","bruttomarginal","vinstmarginal","operativtkassaflodesmarginal", "stockChangePct"]]
    df["stockChangePct"] = df["stockChangePct"].astype(float) * 100
    df = df[df["stockChangePct"] < 10000000]
    
    df = df.dropna()

    X = df.drop(columns=["stockChangePct"])
    Y = df["stockChangePct"];
    
    x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)

    return x_train, y_train, x_test, y_test

# %%
def create_model(x_train, y_train, x_test, y_test):

    """
    Model providing function:

    Create Keras model with double curly brackets dropped-in as needed.
    Return value has to be a valid python dictionary with two customary keys:
        - loss: Specify a numeric evaluation metric to be minimized
        - status: Just use STATUS_OK and see hyperopt documentation if not feasible
    The last one is optional, though recommended, namely:
        - model: specify the model just created so that we can later use it again.
    """
    model = Sequential()
    model.add(Dense({{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}}, input_dim=x_train.shape[1]))
    model.add(Activation({{choice(['relu', 'linear', 'tanh'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense({{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}}))
    model.add(Activation({{choice(['relu','linear', 'tanh'])}}))
    model.add(Dropout({{uniform(0, 1)}}))
    model.add(Dense({{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}}))
    model.add(Activation({{choice(['relu', 'linear','tanh'])}}))
    model.add(Dropout({{uniform(0, 1)}}))


    if {{choice([0, 1])}}:
        model.add(Dense({{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}}))
        model.add(Activation({{choice(['relu', 'linear', 'tanh'])}}))
        model.add(Dropout({{uniform(0, 1)}}))

    if {{choice([0, 1])}}:
        model.add(Dense({{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}}))
        model.add(Activation({{choice(['relu',  'linear', 'tanh'])}}))
        model.add(Dropout({{uniform(0, 1)}}))    
    
    model.add(Dense(1))
    model.add(Activation('linear'))
    
    es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
    
    model.compile(loss='mean_squared_error', metrics=['accuracy'],
                  optimizer={{choice(['rmsprop', 'adam', 'sgd'])}})

    result = model.fit(x_train, y_train,
                        batch_size={{choice([x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3])}},
                        epochs=20,
                        verbose=2,
                        validation_split=0.1,
                        callbacks=[es])
    
    #get the highest validation accuracy of the training epochs
    validation_acc = np.amax(result.history['val_acc']) 
    print('Best validation acc of epoch:', validation_acc)
    return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}

# %%
# x_train, y_train, x_test, y_test = data()
# print(x_train.head())
# print(y_train.head())
# print(x_train.shape)
# print(y_train.head())
best_run, best_model = optim.minimize(model=create_model,
                                      data=data,
                                      algo=tpe.suggest,
                                      max_evals=50,
                                      notebook_name='Groups',
                                      trials=Trials())

x_train, y_train, x_test, y_test = data()
print("Evalutation of best performing model:")
print(best_model.evaluate(x_test, y_test))
print("Best performing model chosen hyper-parameters:")
print(best_run)
# Out:
# >>> Imports:
# #coding=utf-8
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import glob
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from sklearn.preprocessing import MinMaxScaler
# except:
#     pass
#
# try:
#     import seaborn as sns
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     from sklearn.cluster import KMeans
# except:
#     pass
#
# try:
#     from scipy import stats
# except:
#     pass
#
# try:
#     import numpy as np
# except:
#     pass
#
# try:
#     import pandas as pd
# except:
#     pass
#
# try:
#     import seaborn as sns
# except:
#     pass
#
# try:
#     import matplotlib.pyplot as plt
# except:
#     pass
#
# try:
#     from sklearn.metrics import confusion_matrix, precision_score
# except:
#     pass
#
# try:
#     from sklearn.model_selection import train_test_split
# except:
#     pass
#
# try:
#     from keras.layers import Dense, Dropout, Activation
# except:
#     pass
#
# try:
#     from keras.models import Sequential
# except:
#     pass
#
# try:
#     from keras.utils import to_categorical
# except:
#     pass
#
# try:
#     from keras.callbacks import EarlyStopping
# except:
#     pass
#
# try:
#     from hyperopt import Trials, STATUS_OK, tpe
# except:
#     pass
#
# try:
#     from keras.utils import np_utils
# except:
#     pass
#
# try:
#     from hyperas import optim
# except:
#     pass
#
# try:
#     from hyperas.distributions import choice, uniform
# except:
#     pass
#
# >>> Hyperas search space:
#
# def get_space():
#     return {
#         'Dense': hp.choice('Dense', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#         'Activation': hp.choice('Activation', ['relu', 'linear', 'tanh']),
#         'Dropout': hp.uniform('Dropout', 0, 1),
#         'Dense_1': hp.choice('Dense_1', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#         'Activation_1': hp.choice('Activation_1', ['relu','linear', 'tanh']),
#         'Dropout_1': hp.uniform('Dropout_1', 0, 1),
#         'Dense_2': hp.choice('Dense_2', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#         'Activation_2': hp.choice('Activation_2', ['relu', 'linear','tanh']),
#         'Dropout_2': hp.uniform('Dropout_2', 0, 1),
#         'Dropout_3': hp.choice('Dropout_3', [0, 1]),
#         'Dense_3': hp.choice('Dense_3', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#         'Activation_3': hp.choice('Activation_3', ['relu', 'linear', 'tanh']),
#         'Dropout_4': hp.uniform('Dropout_4', 0, 1),
#         'Dropout_5': hp.choice('Dropout_5', [0, 1]),
#         'Dense_4': hp.choice('Dense_4', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#         'Activation_4': hp.choice('Activation_4', ['relu',  'linear', 'tanh']),
#         'Dropout_6': hp.uniform('Dropout_6', 0, 1),
#         'optimizer': hp.choice('optimizer', ['rmsprop', 'adam', 'sgd']),
#         'Dense_5': hp.choice('Dense_5', [x_train.shape[1], x_train.shape[1] * 2, x_train.shape[1] * 3]),
#     }
#
# >>> Data
#   1:
#   2: """
#   3: Data providing function:
#   4:
#   5: This function is separated from create_model() so that hyperopt
#   6: won't reload data for each evaluation run.
#   7: """
#   8: df = pd.read_csv("./kpi.csv", header=0, na_values='.', encoding="utf8")
#   9: df = df[["vinsttillvaxt","omsattningstillvaxt","ebittillvaxt","bruttomarginal","vinstmarginal","operativtkassaflodesmarginal", "stockChangePct"]]
#  10: df["stockChangePct"] = df["stockChangePct"].astype(float) * 100
#  11: df = df[df["stockChangePct"] < 10000000]
#  12:
#  13: df = df.dropna()
#  14:
#  15: X = df.drop(columns=["stockChangePct"])
#  16: Y = df["stockChangePct"];
#  17:
#  18: x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
#  19:
#  20:
#  21:
#  22:
# >>> Resulting replaced keras model:
#
#    1: def keras_fmin_fnct(space):
#    2:
#    3:
#    4:     """
#    5:     Model providing function:
#    6:
#    7:     Create Keras model with double curly brackets dropped-in as needed.
#    8:     Return value has to be a valid python dictionary with two customary keys:
#    9:         - loss: Specify a numeric evaluation metric to be minimized
#   10:         - status: Just use STATUS_OK and see hyperopt documentation if not feasible
#   11:     The last one is optional, though recommended, namely:
#   12:         - model: specify the model just created so that we can later use it again.
#   13:     """
#   14:     model = Sequential()
#   15:     model.add(Dense(space['Dense'], input_dim=x_train.shape[1]))
#   16:     model.add(Activation(space['Activation']))
#   17:     model.add(Dropout(space['Dropout']))
#   18:     model.add(Dense(space['Dense_1']))
#   19:     model.add(Activation(space['Activation_1']))
#   20:     model.add(Dropout(space['Dropout_1']))
#   21:     model.add(Dense(space['Dense_2']))
#   22:     model.add(Activation(space['Activation_2']))
#   23:     model.add(Dropout(space['Dropout_2']))
#   24:
#   25:
#   26:     if space['Dropout_3']:
#   27:         model.add(Dense(space['Dense_3']))
#   28:         model.add(Activation(space['Activation_3']))
#   29:         model.add(Dropout(space['Dropout_4']))
#   30:
#   31:     if space['Dropout_5']:
#   32:         model.add(Dense(space['Dense_4']))
#   33:         model.add(Activation(space['Activation_4']))
#   34:         model.add(Dropout(space['Dropout_6']))
#   35:
#   36:     model.add(Dense(1))
#   37:     model.add(Activation('linear'))
#   38:
#   39:     es = EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=2)
#   40:
#   41:     model.compile(loss='mean_squared_error', metrics=['accuracy'],
#   42:                   optimizer=space['optimizer'])
#   43:
#   44:     result = model.fit(x_train, y_train,
#   45:                         batch_size=space['Dense_5'],
#   46:                         epochs=20,
#   47:                         verbose=2,
#   48:                         validation_split=0.1,
#   49:                         callbacks=[es])
#   50:
#   51:     #get the highest validation accuracy of the training epochs
#   52:     validation_acc = np.amax(result.history['val_acc'])
#   53:     print('Best validation acc of epoch:', validation_acc)
#   54:     return {'loss': -validation_acc, 'status': STATUS_OK, 'model': model}
#   55:
#   0%|                                                                             | 0/50 [00:00<?, ?it/s, best loss: ?]WARNING:tensorflow:From C:\Users\joaki\.conda\envs\3.7\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\joaki\.conda\envs\3.7\lib\site-packages\keras\backend\tensorflow_backend.py:3445: calling dropout (from tensorflow.python.ops.nn_ops) with keep_prob is deprecated and will be removed in a future version.
# Instructions for updating:
# Please use `rate` instead of `keep_prob`. Rate should be set to `rate = 1 - keep_prob`.
# WARNING:tensorflow:From C:\Users\joaki\.conda\envs\3.7\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 3s - loss: 430.8425 - acc: 0.0000e+00 - val_loss: 2159.3963 - val_acc: 0.0000e+00
#
# Epoch 2/20
#  - 0s - loss: 422.0806 - acc: 0.0000e+00 - val_loss: 2158.4363 - val_acc: 0.0000e+00
#
# Epoch 3/20
#  - 0s - loss: 421.0804 - acc: 0.0000e+00 - val_loss: 2155.8433 - val_acc: 0.0000e+00
#
# Epoch 4/20
#  - 0s - loss: 420.5480 - acc: 0.0000e+00 - val_loss: 2154.7236 - val_acc: 0.0000e+00
#
# Epoch 5/20
#  - 0s - loss: 421.0043 - acc: 0.0000e+00 - val_loss: 2154.7499 - val_acc: 0.0000e+00
#
# Epoch 6/20
#  - 0s - loss: 422.7307 - acc: 0.0000e+00 - val_loss: 2155.9312 - val_acc: 0.0000e+00
#
# Epoch 00006: early stopping
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 1s - loss: 425.5561 - acc: 0.0000e+00 - val_loss: 2164.6692 - val_acc: 0.0000e+00
#
# Epoch 2/20
#  - 0s - loss: 423.5424 - acc: 0.0000e+00 - val_loss: 2166.4294 - val_acc: 0.0000e+00
#
# Epoch 3/20
#  - 0s - loss: 423.0545 - acc: 0.0000e+00 - val_loss: 2165.3877 - val_acc: 0.0000e+00
#
# Epoch 00003: early stopping
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 1s - loss: 420.7945 - acc: 0.0000e+00 - val_loss: 2178.7248 - val_acc: 0.0000e+00
#
# Epoch 2/20
#  - 0s - loss: 428.4451 - acc: 0.0000e+00 - val_loss: 2178.4131 - val_acc: 0.0000e+00
#
# Epoch 3/20
#  - 0s - loss: 425.6550 - acc: 0.0000e+00 - val_loss: 2178.1972 - val_acc: 0.0000e+00
#
# Epoch 4/20
#  - 0s - loss: 425.4245 - acc: 0.0000e+00 - val_loss: 2177.2313 - val_acc: 0.0000e+00
#
# Epoch 5/20
#  - 0s - loss: 425.3979 - acc: 0.0000e+00 - val_loss: 2176.0605 - val_acc: 0.0000e+00
#
# Epoch 6/20
#  - 0s - loss: 424.7175 - acc: 0.0000e+00 - val_loss: 2175.9965 - val_acc: 0.0000e+00
#
# Epoch 7/20
#  - 0s - loss: 425.2162 - acc: 0.0000e+00 - val_loss: 2175.4784 - val_acc: 0.0000e+00
#
# Epoch 8/20
#  - 0s - loss: 425.4170 - acc: 0.0000e+00 - val_loss: 2175.0603 - val_acc: 0.0000e+00
#
# Epoch 9/20
#  - 0s - loss: 419.1013 - acc: 0.0000e+00 - val_loss: 2174.5879 - val_acc: 0.0000e+00
#
# Epoch 10/20
#  - 0s - loss: 424.7901 - acc: 0.0000e+00 - val_loss: 2174.1190 - val_acc: 0.0000e+00
#
# Epoch 11/20
#  - 0s - loss: 424.4133 - acc: 0.0000e+00 - val_loss: 2173.5655 - val_acc: 0.0000e+00
#
# Epoch 12/20
#  - 0s - loss: 423.9580 - acc: 0.0000e+00 - val_loss: 2172.2614 - val_acc: 0.0000e+00
#
# Epoch 13/20
#  - 0s - loss: 424.9441 - acc: 0.0000e+00 - val_loss: 2171.1222 - val_acc: 0.0000e+00
#
# Epoch 14/20
#  - 0s - loss: 423.0228 - acc: 0.0000e+00 - val_loss: 2170.8027 - val_acc: 0.0000e+00
#
# Epoch 15/20
#  - 0s - loss: 422.9448 - acc: 0.0000e+00 - val_loss: 2170.1650 - val_acc: 0.0000e+00
#
# Epoch 16/20
#  - 0s - loss: 424.5826 - acc: 0.0000e+00 - val_loss: 2169.5429 - val_acc: 0.0000e+00
#
# Epoch 17/20
#  - 0s - loss: 422.1764 - acc: 0.0000e+00 - val_loss: 2168.9840 - val_acc: 0.0000e+00
#
# Epoch 18/20
#  - 0s - loss: 424.6597 - acc: 0.0000e+00 - val_loss: 2168.3361 - val_acc: 0.0000e+00
#
# Epoch 19/20
#  - 0s - loss: 423.7305 - acc: 0.0000e+00 - val_loss: 2167.7490 - val_acc: 0.0000e+00
#
# Epoch 20/20
#  - 0s - loss: 419.5041 - acc: 0.0000e+00 - val_loss: 2167.6067 - val_acc: 0.0000e+00
#
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 1s - loss: 421.2088 - acc: 0.0000e+00 - val_loss: 2167.2001 - val_acc: 0.0000e+00
#
# Epoch 2/20
#  - 0s - loss: 421.1315 - acc: 0.0000e+00 - val_loss: 2166.2672 - val_acc: 0.0000e+00
#
# Epoch 3/20
#  - 0s - loss: 421.2489 - acc: 0.0000e+00 - val_loss: 2166.8337 - val_acc: 0.0000e+00
# Epoch 4/20
#  - 0s - loss: 421.4527 - acc: 0.0000e+00 - val_loss: 2165.6545 - val_acc: 0.0000e+00
#
# Epoch 5/20
#  - 0s - loss: 420.7416 - acc: 6.7295e-04 - val_loss: 2165.3283 - val_acc: 0.0000e+00
#
# Epoch 6/20
#  - 0s - loss: 420.9197 - acc: 0.0000e+00 - val_loss: 2164.9460 - val_acc: 0.0000e+00
#
# Epoch 7/20
#  - 0s - loss: 420.5367 - acc: 0.0000e+00 - val_loss: 2165.3005 - val_acc: 0.0000e+00
#
# Epoch 8/20
#  - 0s - loss: 420.4338 - acc: 0.0000e+00 - val_loss: 2164.4683 - val_acc: 0.0000e+00
#
# Epoch 9/20
#  - 0s - loss: 421.0730 - acc: 0.0000e+00 - val_loss: 2164.8491 - val_acc: 0.0000e+00
#
# Epoch 10/20
#  - 0s - loss: 421.1260 - acc: 0.0000e+00 - val_loss: 2164.5281 - val_acc: 0.0000e+00
#
# Epoch 00010: early stopping
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 1s - loss: 421.6130 - acc: 0.0000e+00 - val_loss: 2175.6507 - val_acc: 0.0000e+00
#
# Epoch 2/20
#  - 0s - loss: 420.6981 - acc: 0.0000e+00 - val_loss: 2177.2041 - val_acc: 0.0000e+00
#
# Epoch 3/20
#  - 0s - loss: 423.5641 - acc: 0.0000e+00 - val_loss: 2174.3035 - val_acc: 0.0000e+00
#
# Epoch 4/20
#  - 0s - loss: 421.3205 - acc: 0.0000e+00 - val_loss: 2174.0973 - val_acc: 0.0000e+00
#
# Epoch 5/20
#  - 0s - loss: 422.6308 - acc: 0.0000e+00 - val_loss: 2171.6501 - val_acc: 0.0000e+00
#
# Epoch 6/20
#  - 0s - loss: 422.1980 - acc: 0.0000e+00 - val_loss: 2170.5503 - val_acc: 0.0000e+00
#
# Epoch 7/20
#  - 0s - loss: 423.3054 - acc: 0.0000e+00 - val_loss: 2168.7017 - val_acc: 0.0000e+00
#
# Epoch 8/20
#  - 0s - loss: 422.2294 - acc: 0.0000e+00 - val_loss: 2169.1775 - val_acc: 0.0000e+00
#
# Epoch 9/20
#  - 0s - loss: 420.7649 - acc: 0.0000e+00 - val_loss: 2168.3073 - val_acc: 0.0000e+00
#
# Epoch 10/20
#  - 1s - loss: 422.0544 - acc: 0.0000e+00 - val_loss: 2168.3812 - val_acc: 0.0000e+00
#
# Epoch 11/20
#  - 0s - loss: 421.4397 - acc: 0.0000e+00 - val_loss: 2164.0814 - val_acc: 0.0000e+00
#
# Epoch 12/20
#  - 1s - loss: 422.5425 - acc: 0.0000e+00 - val_loss: 2161.6975 - val_acc: 0.0000e+00
#
# Epoch 13/20
#  - 0s - loss: 420.5896 - acc: 0.0000e+00 - val_loss: 2161.4886 - val_acc: 0.0000e+00
#
# Epoch 14/20
#  - 0s - loss: 420.7881 - acc: 0.0000e+00 - val_loss: 2158.7828 - val_acc: 0.0000e+00
#
# Epoch 15/20
#  - 0s - loss: 420.3063 - acc: 0.0000e+00 - val_loss: 2156.9443 - val_acc: 0.0000e+00
#
# Epoch 16/20
#  - 0s - loss: 421.3134 - acc: 0.0000e+00 - val_loss: 2157.2807 - val_acc: 0.0000e+00
#
# Epoch 17/20
#  - 0s - loss: 422.0278 - acc: 0.0000e+00 - val_loss: 2157.2139 - val_acc: 0.0000e+00
#
# Epoch 00017: early stopping
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  - 1s - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
#
#  10%|██████▌                                                           | 5/50 [00:33<05:17,  7.05s/it, best loss: -0.0]
# C:\Users\joaki\.conda\envs\3.7\lib\site-packages\keras\callbacks.py:543: RuntimeWarning: invalid value encountered in less
#   if self.monitor_op(current - self.min_delta, self.best):
# Epoch 2/20
#  - 0s - loss: nan - acc: 0.0000e+00 - val_loss: nan - val_acc: 0.0000e+00
#
# Epoch 00002: early stopping
# Best validation acc of epoch:
# 0.0
# Train on 1486 samples, validate on 166 samples
# Epoch 1/20
#  12%|███████▉                                                          | 6/50 [00:34<04:00,  5.45s/it, best loss: -0.0]

# %%
df = pd.read_csv("./kpi.csv", header=0, na_values='.')
df = df[["vinsttillvaxt","omsattningstillvaxt","ebittillvaxt","bruttomarginal","vinstmarginal","operativtkassaflodesmarginal", "stockChangePct"]]
df["stockChangePct"] = df["stockChangePct"].astype(float)
df = df[df["stockChangePct"] < 10000000]
# df = df[df["stockChangePct"] > 10000000]
# df["bull"] = np.where((df.stockChangePct> 0), 1, 0)
df = df.dropna()

df.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a08012fc7093> in <module>
# ----> 1 df = pd.read_csv("./kpi.csv", header=0, na_values='.')
#       2 df = df[["vinsttillvaxt","omsattningstillvaxt","ebittillvaxt","bruttomarginal","vinstmarginal","operativtkassaflodesmarginal", "stockChangePct"]]
#       3 df["stockChangePct"] = df["stockChangePct"].astype(float)
#       4 df = df[df["stockChangePct"] < 10000000]
#       5 # df = df[df["stockChangePct"] > 10000000]
#
# NameError: name 'pd' is not defined
