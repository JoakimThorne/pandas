# %%
import pandas as pd
import glob
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler
import seaborn as sns
import numpy as np

# %%
df = pd.read_csv("./kpi.csv", header=0, na_values='.');
df.head()
# Out:
#    ticker  year  period                                  reportEndDate  \
# 0     247  2018       3  Tue Oct 30 2018 00:00:00 GMT+0100 (GMT+01:00)
# 1     247  2018       2  Mon Jul 30 2018 00:00:00 GMT+0200 (GMT+02:00)
# 2     247  2018       1  Tue May 01 2018 00:00:00 GMT+0200 (GMT+02:00)
# 3     247  2017       3  Mon Oct 30 2017 00:00:00 GMT+0100 (GMT+01:00)
# 4  2CUREX  2018       3  Tue Oct 30 2018 00:00:00 GMT+0100 (GMT+01:00)
#
#    bruttomarginal  operativtkassaflodesmarginal  vinsttillvaxt  ebittillvaxt  \
# 0       56.972054                      6.886116            NaN           NaN
# 1       53.558216                     62.985123            NaN           NaN
# 2       55.590099                    -19.031630            NaN           NaN
# 3             NaN                           NaN            NaN           NaN
# 4       39.222061                   -112.652832            NaN           NaN
#
#    omsattningstillvaxt  vinst/aktie  ...  fcf/aktie  rorelsemarginal  \
# ...

# %%
test = df[["vinsttillvaxt", "stockChangePct"]]

test = test[test["vinsttillvaxt"] > 0]
test = test[test["vinsttillvaxt"] < 100000]


test["vinsttillvaxt"] = test["vinsttillvaxt"].astype(int)
test["stockChangePct"] = test["stockChangePct"].astype(float)

test = test[test["stockChangePct"] < 100000]




bins = [0, 5, 10, 15, 20,30,40,50, np.inf]
names = ['<5', '5-10', '10-15', '15-20', '20-30', '30-40', '40-50', '50+']

test['vinsttillvaxtRange'] = pd.cut(test['vinsttillvaxt'], bins, labels=names)


test = test.dropna()

print(np.isinf(test["stockChangePct"]).sum())

# print(test.dtypes)
# Out:
# 0

# %%
plt.figure(figsize=(20,20))

sns.violinplot(x="vinsttillvaxtRange", y="stockChangePct", data=test)
plt.show()

# %%
bins = [0, 5, 10, 15, 20,30,40,50]
names = ['<5', '5-10', '10-15', '15-20', '20-30', '30-40', '40-50']

test['vinsttillvaxtRange'] = pd.cut(test['vinsttillvaxt'], bins, labels=names)


test = test.dropna()

print(np.isinf(test["stockChangePct"]).sum())


plt.figure(figsize=(20,20))
sns.violinplot(x="vinsttillvaxtRange", y="stockChangePct", data=test)
plt.show()
# Out:
# 0

# %%
dist = df.copy();
 
for column in dist:
    print(column)
    print(pd.isnull(dist[column]).sum())
    
dist = dist[["bruttomarginal", "operativtkassaflodesmarginal", "omsattningstillvaxt", "vinst/aktie", "egetkapital/aktie", "fcf/aktie", "rorelsemarginal","ebita/aktie","ebit/aktie","operativkassaflode/aktie","aretskassaflode/aktie","vinstmarginal","stockChange","stockChangePct"]]
# dist = dist[["bruttomarginal", "operativtkassaflodesmarginal", "vinst/aktie", "egetkapital/aktie", "fcf/aktie", "rorelsemarginal","ebita/aktie","ebit/aktie","operativkassaflode/aktie","aretskassaflode/aktie","vinstmarginal","stockChange","stockChangePct"]]

dist.head()
# Out:
# ticker
# 0
# year
# 0
# period
# 0
# reportEndDate
# 0
# bruttomarginal
# 893
# operativtkassaflodesmarginal
# 1059
# vinsttillvaxt
# 4286
# ebittillvaxt
# 4092
# omsattningstillvaxt
# 1408
# vinst/aktie
# 15
# egetkapital/aktie
# 410
# fcf/aktie
# 531
# rorelsemarginal
# 587
# ebita/aktie
# 6
# ebit/aktie
# 5
# operativkassaflode/aktie
# 530
# aretskassaflode/aktie
# 564
# vinstmarginal
# 594
# price
# 601
# stockChange
# 376
# stockChangePct
# 376
#    bruttomarginal  operativtkassaflodesmarginal  omsattningstillvaxt  \
# 0       56.972054                      6.886116                  NaN
# 1       53.558216                     62.985123                  NaN
# 2       55.590099                    -19.031630                  NaN
# 3             NaN                           NaN                  NaN
# 4       39.222061                   -112.652832                  NaN
#
#    vinst/aktie  egetkapital/aktie  fcf/aktie  rorelsemarginal  ebita/aktie  \
# ...

# %%
print(dist.shape)
dist["stockChangePct"] = dist["stockChangePct"].astype(float)
dist["stockChange"] = dist["stockChange"].astype(float)
dist = dist[dist["stockChangePct"] < 100000]
dist = dist[dist["stockChange"] < 100000]
dist = dist.dropna()
print(dist.shape)
# Out:
# (7024, 14)
# (4784, 14)

# %%
# for column in dist:
#     print(dist.shape)
#     dist = dist[dist[column] < dist[column].quantile(.90)]
#     print(dist.shape)

# for column in dist:
#     if "stockChange" not in column: 
#         plt.figure(figsize=(20,20))
#         sns.jointplot(column, "stockChangePct", data=dist)
#         plt.show()

# %%
# dist = dist[dist["stockChange"] > 0]
dist = dist[dist["vinstmarginal"] > -1000]

dist = dist[dist["bruttomarginal"] > -1000]
dist = dist[dist["bruttomarginal"] < 1000]

dist = dist[dist["operativtkassaflodesmarginal"] > -2000]
dist = dist[dist["operativtkassaflodesmarginal"] < 2000]

dist = dist[dist["omsattningstillvaxt"] < 8000]

dist = dist[dist["vinst/aktie"] < 100]

dist = dist[dist["egetkapital/aktie"] < 600]
dist = dist[dist["egetkapital/aktie"] > -200]

dist = dist[dist["fcf/aktie"] < 200]
dist = dist[dist["fcf/aktie"] > -200]

dist = dist[dist["rorelsemarginal"] < 500]

dist = dist[dist["ebita/aktie"] < 55]
dist = dist[dist["ebita/aktie"] > -55]

dist = dist[dist["operativkassaflode/aktie"] < 55]
dist = dist[dist["operativkassaflode/aktie"] > -55]

dist = dist[dist["aretskassaflode/aktie"] < 60]
dist = dist[dist["aretskassaflode/aktie"] > -60]

dist = dist[dist["vinstmarginal"] < 1000]


for column in dist:
    if "stockChange" not in column: 
        plt.figure(figsize=(20,20))
        sns.jointplot(column, "stockChangePct", data=dist)
        plt.show()

# %%
dist["bull"] = dist["stockChangePct"] > 0

prognos = dist[["bruttomarginal", "operativtkassaflodesmarginal", "omsattningstillvaxt", "vinst/aktie", "egetkapital/aktie", "fcf/aktie", "rorelsemarginal","ebita/aktie","ebit/aktie","operativkassaflode/aktie","aretskassaflode/aktie","vinstmarginal","bull"]]
prognos.head()
# Out:
#     bruttomarginal  operativtkassaflodesmarginal  omsattningstillvaxt  \
# 5       -90.366768                   -265.305939            19.541096
# 20       46.857288                   -143.219696           296.544769
# 21       62.997341                    -57.899956           309.769196
# 22       74.123901                    -24.559122           243.200775
# 23       83.596214                   -213.123032           -18.109016
#
#     vinst/aktie  egetkapital/aktie  fcf/aktie  rorelsemarginal  ebita/aktie  \
# 5       -0.4110           1.894435  -0.356193      -382.220428    -0.398560
# 20      -0.1887           6.776490  -0.271950      -104.263596    -0.361315
# 21      -0.2771           7.013237  -0.242534       -73.100876    -0.090277
# 22      -0.2236           8.077858  -0.566658       -72.366043    -0.065354
# 23      -0.2871           1.369248  -0.238827      -286.813873    -0.229396
#
#     ebit/aktie  operativkassaflode/aktie  aretskassaflode/aktie  \
# ...

# %%
#corelation matrix.
corr= prognos.corr()
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig=plt.gcf()
fig.set_size_inches(12,10)
sns.heatmap(data=corr,mask=mask,square=True,annot=True,cbar=True,cmap=plt.cm.Reds)

# %%
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.metrics import accuracy_score
from sklearn.metrics import confusion_matrix


X = prognos[["bruttomarginal", "operativtkassaflodesmarginal", "omsattningstillvaxt", "vinst/aktie", "egetkapital/aktie", "fcf/aktie", "rorelsemarginal","ebita/aktie","ebit/aktie","operativkassaflode/aktie","aretskassaflode/aktie","vinstmarginal"]]
X = preprocessing.scale(X)
Y = prognos[["bull"]]

x_train, x_test, y_train, y_test = train_test_split(X, Y, test_size=0.3, random_state=0)
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((3119, 12), (1338, 12), (3119, 1), (1338, 1))

# %%
from sklearn.linear_model import SGDClassifier
clf = SGDClassifier(loss="hinge", penalty="l2", max_iter=100)
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
print(accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# 0.5747384155455905
# [[524 224]
#  [345 245]]
# C:\Users\joaki\.conda\envs\3.7\lib\site-packages\sklearn\linear_model\stochastic_gradient.py:183: FutureWarning: max_iter and tol parameters have been added in SGDClassifier in 0.19. If max_iter is set but tol is left unset, the default value for tol in 0.19 and 0.20 will be None (which is equivalent to -infinity, so it has no effect) but will change in 0.21 to 1e-3. Specify tol to silence this warning.
#   FutureWarning)
# C:\Users\joaki\.conda\envs\3.7\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
from sklearn import svm
clf = svm.SVC(gamma='scale')
clf.fit(x_train, y_train)
predictions = clf.predict(x_test)
print(accuracy_score(y_test, predictions))
print(confusion_matrix(y_test, predictions))
# Out:
# C:\Users\joaki\.conda\envs\3.7\lib\site-packages\sklearn\utils\validation.py:761: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# 0.5710014947683109
# [[658  90]
#  [484 106]]

# %%
from tensorflow.python.client import device_lib

device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 4231163670322037423, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 1416668364
#  locality {
#    bus_id: 1
#    links {
#    }
#  }
#  incarnation: 1444710490516923342
#  physical_device_desc: "device: 0, name: GeForce GTX 1050, pci bus id: 0000:01:00.0, compute capability: 6.1"]

# %%
from keras.models import Sequential
from keras import layers
 
input_dim = x_train.shape[1]  # Number of features

model = Sequential()
model.add(layers.Dense(24, input_dim=input_dim, activation='relu'))
model.add(layers.Dense(48, activation='relu'))
# model.add(layers.Dropout(.8))

model.add(layers.Dense(96, activation='relu'))
# model.add(layers.Dropout(.8))

model.add(layers.Dense(72, activation='relu'))
# model.add(layers.Dropout(.8))
model.add(layers.Dense(48, activation='relu'))

model.add(layers.Dense(24, activation='relu'))

model.add(layers.Dense(12, activation='relu'))

model.add(layers.Dense(1, activation='sigmoid'))

# %%
model.compile(loss='binary_crossentropy', 
               optimizer='adam', 
               metrics=['accuracy'])
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_15 (Dense)             (None, 24)                312
# _________________________________________________________________
# dense_16 (Dense)             (None, 48)                1200
# _________________________________________________________________
# dense_17 (Dense)             (None, 96)                4704
# _________________________________________________________________
# dense_18 (Dense)             (None, 72)                6984
# _________________________________________________________________
# dense_19 (Dense)             (None, 48)                3504
# _________________________________________________________________
# dense_20 (Dense)             (None, 24)                1176
# _________________________________________________________________
# dense_21 (Dense)             (None, 12)                300
# ...

# %%
from keras.callbacks import EarlyStopping

es = EarlyStopping(monitor='val_loss', mode='min', patience=10)

model_output = model.fit(x_train, y_train,
                    epochs=1000,
                    verbose=10,
                    validation_data=(x_test, y_test),
                    batch_size=10,
                    callbacks=[es])
# Out:
# Train on 3119 samples, validate on 1338 samples
# Epoch 1/1000
# Epoch 2/1000
# Epoch 3/1000
# Epoch 4/1000
# Epoch 5/1000
# Epoch 6/1000
# Epoch 7/1000
# Epoch 8/1000
# Epoch 9/1000
# Epoch 10/1000
# Epoch 11/1000
# Epoch 12/1000
# Epoch 13/1000
# Epoch 14/1000
# Epoch 15/1000

# %%
loss, accuracy = model.evaluate(x_train, y_train, verbose=False)
print("Training Accuracy: {:.4f}".format(accuracy))
loss, accuracy = model.evaluate(x_test, y_test, verbose=False)
print("Testing Accuracy:  {:.4f}".format(accuracy))


print('Training Accuracy : ' , np.mean(model_output.history["acc"]))
print('Validation Accuracy : ' , np.mean(model_output.history["val_acc"]))



# Plot training & validation accuracy values
plt.plot(model_output.history['acc'])
plt.plot(model_output.history['val_acc'])
plt.title('Model accuracy')
plt.ylabel('Accuracy')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()

# Plot training & validation loss values
plt.plot(model_output.history['loss'])
plt.plot(model_output.history['val_loss'])
plt.title('model_output loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['Train', 'Test'], loc='upper left')
plt.show()
# Out:
# Training Accuracy: 0.6374
# Testing Accuracy:  0.5800
# Training Accuracy :  0.6220369820218573
# Validation Accuracy :  0.5841056355030665

# %%
print(prognos[prognos["bruttomarginal"] > 0 ].bull.value_counts())
print(prognos[prognos["operativtkassaflodesmarginal"] > 0 ].bull.value_counts())
print(prognos[prognos["omsattningstillvaxt"] > 0 ].bull.value_counts())
print(prognos[prognos["vinst/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["egetkapital/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["fcf/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["rorelsemarginal"] > 0 ].bull.value_counts())
print(prognos[prognos["ebita/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["ebit/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["operativkassaflode/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["aretskassaflode/aktie"] > 0 ].bull.value_counts())
print(prognos[prognos["vinstmarginal"] > 0 ].bull.value_counts())
# Out:
# False    2265
# True     1866
# Name: bull, dtype: int64
# True     1304
# False    1302
# Name: bull, dtype: int64
# False    1768
# True     1551
# Name: bull, dtype: int64
# True     1388
# False    1362
# Name: bull, dtype: int64
# False    2428
# True     1954
# Name: bull, dtype: int64
# True     930
# False    929
# Name: bull, dtype: int64
# False    1416
# True     1414
# Name: bull, dtype: int64
# False    1558
# True     1513
# Name: bull, dtype: int64
# False    1416
# True     1414
# Name: bull, dtype: int64
# True     1304
# False    1302
# Name: bull, dtype: int64
# False    1080
# True     1007
# Name: bull, dtype: int64
# True     1375
# False    1335
# Name: bull, dtype: int64

# %%
temp = prognos[prognos["bull"] == True]
corr= prognos.corr()
mask = np.array(corr)
mask[np.tril_indices_from(mask)] = False
fig=plt.gcf()
fig.set_size_inches(12,10)
sns.heatmap(data=corr,mask=mask,square=True,annot=True,cbar=True,cmap=plt.cm.Reds)
